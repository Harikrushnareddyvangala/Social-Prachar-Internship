# %% [markdown]
# #### In Any programming language we can look upto the below basics, While writing a program

# %% [raw]
# 1. writing comments fro the program
# 2. writing data values and knowing datatypes of values
# 3. values as standard input& user input
#      3.1. Type casting
# 4. Storing value/s to a variable
# 5. working values/variables with the operators (arithmetic, logical, comparission ex.+,-,*,and,or..)
# 6. Displaying output in a program

# %%
10+20
# Out:
# 30
